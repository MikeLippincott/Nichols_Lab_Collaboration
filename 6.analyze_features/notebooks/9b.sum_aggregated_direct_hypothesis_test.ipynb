# %%
import pathlib

import numpy as np
import pandas as pd

# %%
file_path = pathlib.Path(
    "../../data/6.analysis_results/sum_aggregated_levene_test_results.csv"
).resolve(strict=True)


df = pd.read_csv(file_path, index_col=0).reset_index(drop=True)
df
# Out:
#                           feature  levene_statistic  levene_p_value  \
# 0                  AreaShape_Area          1.312482    2.570925e-01
# 1                  AreaShape_Area          1.583091    2.137293e-01
# 2                  AreaShape_Area          5.121513    2.775241e-02
# 3     AreaShape_CentralMoment_0_0          1.312482    2.570925e-01
# 4     AreaShape_CentralMoment_0_0          1.583091    2.137293e-01
# ..                            ...               ...             ...
# 727  Texture_Variance_OP_3_02_256         31.005530    8.311402e-07
# 728  Texture_Variance_OP_3_02_256         20.806708    3.042424e-05
# 729  Texture_Variance_OP_3_03_256          2.596131    1.130651e-01
# 730  Texture_Variance_OP_3_03_256         31.684924    6.662003e-07
# 731  Texture_Variance_OP_3_03_256         21.093302    2.733474e-05
#
#              group  holm_bonferroni_p_value
# 0    high_vs_unsel                 0.427459
# 1       high_vs_wt                 0.427459
# 2      unsel_vs_wt                 0.083257
# 3    high_vs_unsel                 0.427459
# 4       high_vs_wt                 0.427459
# ..             ...                      ...
# 727     high_vs_wt                 0.000002
# 728    unsel_vs_wt                 0.000061
# 729  high_vs_unsel                 0.113065
# 730     high_vs_wt                 0.000002
# 731    unsel_vs_wt                 0.000055
#
# [732 rows x 5 columns]

# %%
# subset the data
high_vs_wt = df.loc[df["group"] == "high_vs_wt"]
unsel_vs_wt = df.loc[df["group"] == "unsel_vs_wt"]
high_vs_unsel = df.loc[df["group"] == "high_vs_unsel"]

high_vs_wt.rename(
    columns={
        "levene_p_value": "high_vs_wt_levene_p_value",
        "holm_bonferroni_p_value": "high_vs_wt_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)
unsel_vs_wt.rename(
    columns={
        "levene_p_value": "unsel_vs_wt_levene_p_value",
        "holm_bonferroni_p_value": "unsel_vs_wt_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)
high_vs_unsel.rename(
    columns={
        "levene_p_value": "high_vs_unsel_levene_p_value",
        "holm_bonferroni_p_value": "high_vs_unsel_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)


# drop columns
high_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
unsel_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
high_vs_unsel.drop(columns=["group", "levene_statistic"], inplace=True)


# combine the data
combined_df = pd.merge(high_vs_wt, unsel_vs_wt, on="feature")
combined_df = pd.merge(combined_df, high_vs_unsel, on="feature")
combined_df.head()
# Out:
# /tmp/ipykernel_819469/3310347519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_wt.rename(
# /tmp/ipykernel_819469/3310347519.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsel_vs_wt.rename(
# /tmp/ipykernel_819469/3310347519.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_unsel.rename(
# /tmp/ipykernel_819469/3310347519.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
# /tmp/ipykernel_819469/3310347519.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsel_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
# /tmp/ipykernel_819469/3310347519.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_unsel.drop(columns=["group", "levene_statistic"], inplace=True)
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area                   0.213729
# 1  AreaShape_CentralMoment_0_0                   0.213729
# 2  AreaShape_CentralMoment_0_1                   0.001972
# 3  AreaShape_CentralMoment_0_2                   0.000078
# 4  AreaShape_CentralMoment_0_3                   0.275653
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                                   0.427459                    0.027752
# 1                                   0.427459                    0.027752
# 2                                   0.005917                    0.004941
# 3                                   0.000234                    0.005849
# 4                                   0.275653                    0.005932
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.083257                      0.257092
# 1                                    0.083257                      0.257092
# 2                                    0.009882                      0.872488
# 3                                    0.011699                      0.927179
# 4                                    0.017795                      0.026744
#
#    high_vs_unsel_levene_p_value_holm_bonferroni
# 0                                      0.427459
# 1                                      0.427459
# 2                                      0.872488
# 3                                      0.927179
# 4                                      0.053488

# %%
variance_df_path = pathlib.Path(
    "../../data/6.analysis_results/sum_aggregated_variance_results_each_feature.csv"
).resolve(strict=True)
variance_df = pd.read_csv(variance_df_path)
variance_df.head()
# Out:
#   Metadata_genotype                      feature  variance
# 0              high               AreaShape_Area  0.516762
# 1              high  AreaShape_CentralMoment_0_0  0.516762
# 2              high  AreaShape_CentralMoment_0_1  2.361025
# 3              high  AreaShape_CentralMoment_0_2  1.147158
# 4              high  AreaShape_CentralMoment_0_3  0.716030

# %%
# replace metadata genotype with the correct group
variance_df["Metadata_genotype"].replace(
    {"high": "High-Severity", "unsel": "Mid-Severity", "wt": "Wild Type"}, inplace=True
)
variance_df.head()
# Out:
#   Metadata_genotype                      feature  variance
# 0     High-Severity               AreaShape_Area  0.516762
# 1     High-Severity  AreaShape_CentralMoment_0_0  0.516762
# 2     High-Severity  AreaShape_CentralMoment_0_1  2.361025
# 3     High-Severity  AreaShape_CentralMoment_0_2  1.147158
# 4     High-Severity  AreaShape_CentralMoment_0_3  0.716030

# %%
high_severity = variance_df.loc[variance_df["Metadata_genotype"] == "High-Severity"]
mid_severity = variance_df.loc[variance_df["Metadata_genotype"] == "Mid-Severity"]
wt = variance_df.loc[variance_df["Metadata_genotype"] == "Wild Type"]

# rename the columns
high_severity.rename(columns={"variance": "high_severity_variance"}, inplace=True)
mid_severity.rename(columns={"variance": "mid_severity_variance"}, inplace=True)
wt.rename(columns={"variance": "wild_type_severity_variance"}, inplace=True)

# drop columns
high_severity.drop(columns=["Metadata_genotype"], inplace=True)
mid_severity.drop(columns=["Metadata_genotype"], inplace=True)
wt.drop(columns=["Metadata_genotype"], inplace=True)

high_severity.reset_index(drop=True, inplace=True)
mid_severity.reset_index(drop=True, inplace=True)
wt.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_819469/421898067.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_severity.rename(columns={"variance": "high_severity_variance"}, inplace=True)
# /tmp/ipykernel_819469/421898067.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_severity.rename(columns={"variance": "mid_severity_variance"}, inplace=True)
# /tmp/ipykernel_819469/421898067.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt.rename(columns={"variance": "wild_type_severity_variance"}, inplace=True)
# /tmp/ipykernel_819469/421898067.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_severity.drop(columns=["Metadata_genotype"], inplace=True)
# /tmp/ipykernel_819469/421898067.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_severity.drop(columns=["Metadata_genotype"], inplace=True)
# /tmp/ipykernel_819469/421898067.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt.drop(columns=["Metadata_genotype"], inplace=True)

# %%
all_severities = pd.merge(
    mid_severity, high_severity, left_on="feature", right_on="feature"
)
all_severities = pd.merge(all_severities, wt, left_on="feature", right_on="feature")
combined_df = pd.merge(combined_df, all_severities, on="feature")
combined_df.head()
# Out:
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area                   0.213729
# 1  AreaShape_CentralMoment_0_0                   0.213729
# 2  AreaShape_CentralMoment_0_1                   0.001972
# 3  AreaShape_CentralMoment_0_2                   0.000078
# 4  AreaShape_CentralMoment_0_3                   0.275653
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                                   0.427459                    0.027752
# 1                                   0.427459                    0.027752
# 2                                   0.005917                    0.004941
# 3                                   0.000234                    0.005849
# 4                                   0.275653                    0.005932
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.083257                      0.257092
# 1                                    0.083257                      0.257092
# 2                                    0.009882                      0.872488
# 3                                    0.011699                      0.927179
# 4                                    0.017795                      0.026744
#
#    high_vs_unsel_levene_p_value_holm_bonferroni  mid_severity_variance  \
# 0                                      0.427459               1.080019
# 1                                      0.427459               1.080019
# 2                                      0.872488               2.315194
# 3                                      0.927179               1.569349
# 4                                      0.053488               3.864689
#
#    high_severity_variance  wild_type_severity_variance
# 0                0.516762                     0.250290
# 1                0.516762                     0.250290
# 2                2.361025                     0.294862
# 3                1.147158                     0.167498
# 4                0.716030                     0.488715

# %%
# make a new column that contains permutation test results for each feature
np.random.seed(0)
n_permutations = 1000
# permute each column
permuted_df = combined_df.copy()
for column in permuted_df.columns:
    if column != "feature":
        permuted_df[column] = np.random.permutation(permuted_df[column].values)

# %%
combined_df.head()
# Out:
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area                   0.213729
# 1  AreaShape_CentralMoment_0_0                   0.213729
# 2  AreaShape_CentralMoment_0_1                   0.001972
# 3  AreaShape_CentralMoment_0_2                   0.000078
# 4  AreaShape_CentralMoment_0_3                   0.275653
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                                   0.427459                    0.027752
# 1                                   0.427459                    0.027752
# 2                                   0.005917                    0.004941
# 3                                   0.000234                    0.005849
# 4                                   0.275653                    0.005932
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.083257                      0.257092
# 1                                    0.083257                      0.257092
# 2                                    0.009882                      0.872488
# 3                                    0.011699                      0.927179
# 4                                    0.017795                      0.026744
#
#    high_vs_unsel_levene_p_value_holm_bonferroni  mid_severity_variance  \
# 0                                      0.427459               1.080019
# 1                                      0.427459               1.080019
# 2                                      0.872488               2.315194
# 3                                      0.927179               1.569349
# 4                                      0.053488               3.864689
#
#    high_severity_variance  wild_type_severity_variance
# 0                0.516762                     0.250290
# 1                0.516762                     0.250290
# 2                2.361025                     0.294862
# 3                1.147158                     0.167498
# 4                0.716030                     0.488715

# %% [markdown]
# We now identify which complexes match the exact hypothesis of the problem.
# The hypothesis is that the high-severity and wild type genotype complexes have less morphology variance than that of the unselected severity genotype complexes.
# In addition there should be no statistically significant difference between the variance of morphology high-severity and wild type genotype complexes.

# %%
dict_of_dfs = {"non_permuted": combined_df, "permuted": permuted_df}
output_dfs = {"non_permuted": "", "permuted": ""}
for data_shuffle_df in dict_of_dfs:
    df = dict_of_dfs[data_shuffle_df]
    # variance logic
    # wt < mid
    # mid > high
    df["variance_pattern_bool"] = np.where(
        (df["high_severity_variance"] < df["mid_severity_variance"])
        & (df["wild_type_severity_variance"] < df["mid_severity_variance"]),
        True,
        False,
    )
    # levene logic
    # high_vs_unsel <0.05
    # wt_vs_unsel <0.05
    # high_vs_wt >0.05
    df["significance_bool_holm_bonferroni"] = np.where(
        (df["high_vs_unsel_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["unsel_vs_wt_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["high_vs_wt_levene_p_value_holm_bonferroni"] > 0.05),
        True,
        False,
    )

    df["significance_bool_half_baked_holm_bonferroni"] = np.where(
        (df["high_vs_unsel_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["unsel_vs_wt_levene_p_value_holm_bonferroni"] < 0.05),
        True,
        False,
    )

    df["hypothesis_test_bool"] = np.where(
        (df["variance_pattern_bool"] == True)
        & (df["significance_bool_holm_bonferroni"] == True),
        True,
        False,
    )
    df["hypothesis_test_bool_half_baked"] = np.where(
        (df["variance_pattern_bool"] == True)
        & (df["significance_bool_half_baked_holm_bonferroni"] == True),
        True,
        False,
    )

    output_dfs[data_shuffle_df] = df

# %%
list_of_enrichment_dfs = []
for data_shuffle_df in output_dfs:
    df = output_dfs[data_shuffle_df]
    # split the feature column
    df[
        [
            "feature_group",
            "measurement",
            "bone",
            "parameter1",
            "parameter2",
            "parameter3",
        ]
    ] = df["feature"].str.split("_", expand=True)

    # get counts of each feature group and the hypothesis test bool
    hypothesis_tests_half_baked_df = (
        df.groupby(
            [
                "feature_group",
                "variance_pattern_bool",
                "significance_bool_half_baked_holm_bonferroni",
                "hypothesis_test_bool_half_baked",
            ]
        )
        .size()
        .reset_index(name="counts")
    )
    hypothesis_tests_half_baked_df["permutation"] = data_shuffle_df
    list_of_enrichment_dfs.append(hypothesis_tests_half_baked_df)
final_enrichment_half_baked_df = pd.concat(list_of_enrichment_dfs)
final_enrichment_half_baked_df.reset_index(drop=True, inplace=True)

# %%
list_of_enrichment_dfs = []
for data_shuffle_df in output_dfs:
    df = output_dfs[data_shuffle_df]
    # split the feature column
    df[
        [
            "feature_group",
            "measurement",
            "bone",
            "parameter1",
            "parameter2",
            "parameter3",
        ]
    ] = df["feature"].str.split("_", expand=True)

    # get counts of each feature group and the hypothesis test bool
    hypothesis_tests_df = (
        df.groupby(
            [
                "feature_group",
                "variance_pattern_bool",
                "significance_bool_holm_bonferroni",
                "hypothesis_test_bool",
            ]
        )
        .size()
        .reset_index(name="counts")
    )
    hypothesis_tests_df["permutation"] = data_shuffle_df
    list_of_enrichment_dfs.append(hypothesis_tests_df)
final_enrichment_df = pd.concat(list_of_enrichment_dfs)
final_enrichment_df.reset_index(drop=True, inplace=True)

# %%
final_enrichment_half_baked_df.head(60)
# Out:
#          feature_group  variance_pattern_bool  \
# 0            AreaShape                  False
# 1            AreaShape                  False
# 2            AreaShape                   True
# 3            AreaShape                   True
# 4          Granularity                  False
# 5          Granularity                  False
# 6          Granularity                   True
# 7            Intensity                  False
# 8            Intensity                  False
# 9            Intensity                   True
# 10           Neighbors                   True
# 11  RadialDistribution                  False
# 12  RadialDistribution                  False
# 13  RadialDistribution                   True
# 14  RadialDistribution                   True
# 15             Texture                  False
# 16             Texture                  False
# 17             Texture                   True
# 18           AreaShape                  False
# 19           AreaShape                  False
# 20           AreaShape                   True
# 21           AreaShape                   True
# 22         Granularity                  False
# 23         Granularity                   True
# 24         Granularity                   True
# 25           Intensity                  False
# 26           Intensity                  False
# 27           Intensity                   True
# 28           Neighbors                  False
# 29           Neighbors                  False
# 30           Neighbors                   True
# 31  RadialDistribution                  False
# 32  RadialDistribution                  False
# 33  RadialDistribution                   True
# 34  RadialDistribution                   True
# 35             Texture                  False
# 36             Texture                  False
# 37             Texture                   True
# 38             Texture                   True
#
#     significance_bool_half_baked_holm_bonferroni  \
# 0                                          False
# 1                                           True
# 2                                          False
# 3                                           True
# 4                                          False
# 5                                           True
# 6                                          False
# 7                                          False
# 8                                           True
# 9                                          False
# 10                                         False
# 11                                         False
# 12                                          True
# 13                                         False
# 14                                          True
# 15                                         False
# 16                                          True
# 17                                         False
# 18                                         False
# 19                                          True
# 20                                         False
# 21                                          True
# 22                                         False
# 23                                         False
# 24                                          True
# 25                                         False
# 26                                          True
# 27                                         False
# 28                                         False
# 29                                          True
# 30                                          True
# 31                                         False
# 32                                          True
# 33                                         False
# 34                                          True
# 35                                         False
# 36                                          True
# 37                                         False
# 38                                          True
#
#     hypothesis_test_bool_half_baked  counts   permutation
# 0                             False      32  non_permuted
# 1                             False       4  non_permuted
# 2                             False      60  non_permuted
# 3                              True       2  non_permuted
# 4                             False       3  non_permuted
# 5                             False       1  non_permuted
# 6                             False       2  non_permuted
# 7                             False       9  non_permuted
# 8                             False       5  non_permuted
# 9                             False       1  non_permuted
# 10                            False       3  non_permuted
# 11                            False      34  non_permuted
# 12                            False      13  non_permuted
# 13                            False      20  non_permuted
# 14                             True       3  non_permuted
# 15                            False      27  non_permuted
# 16                            False      14  non_permuted
# 17                            False      11  non_permuted
# 18                            False      45      permuted
# 19                            False      13      permuted
# 20                            False      34      permuted
# 21                             True       6      permuted
# 22                            False       2      permuted
# 23                            False       3      permuted
# 24                             True       1      permuted
# 25                            False      10      permuted
# 26                            False       2      permuted
# 27                            False       3      permuted
# 28                            False       1      permuted
# 29                            False       1      permuted
# 30                             True       1      permuted
# 31                            False      28      permuted
# 32                            False       4      permuted
# 33                            False      29      permuted
# 34                             True       9      permuted
# 35                            False      26      permuted
# 36                            False       3      permuted
# 37                            False      19      permuted
# 38                             True       4      permuted

# %%
final_enrichment_df.head(60)
# Out:
#          feature_group  variance_pattern_bool  \
# 0            AreaShape                  False
# 1            AreaShape                   True
# 2            AreaShape                   True
# 3          Granularity                  False
# 4          Granularity                   True
# 5            Intensity                  False
# 6            Intensity                   True
# 7            Neighbors                   True
# 8   RadialDistribution                  False
# 9   RadialDistribution                   True
# 10  RadialDistribution                   True
# 11             Texture                  False
# 12             Texture                   True
# 13           AreaShape                  False
# 14           AreaShape                  False
# 15           AreaShape                   True
# 16           AreaShape                   True
# 17         Granularity                  False
# 18         Granularity                   True
# 19           Intensity                  False
# 20           Intensity                   True
# 21           Neighbors                  False
# 22           Neighbors                   True
# 23  RadialDistribution                  False
# 24  RadialDistribution                  False
# 25  RadialDistribution                   True
# 26  RadialDistribution                   True
# 27             Texture                  False
# 28             Texture                  False
# 29             Texture                   True
# 30             Texture                   True
#
#     significance_bool_holm_bonferroni  hypothesis_test_bool  counts  \
# 0                               False                 False      36
# 1                               False                 False      61
# 2                                True                  True       1
# 3                               False                 False       4
# 4                               False                 False       2
# 5                               False                 False      14
# 6                               False                 False       1
# 7                               False                 False       3
# 8                               False                 False      47
# 9                               False                 False      21
# 10                               True                  True       2
# 11                              False                 False      41
# 12                              False                 False      11
# 13                              False                 False      50
# 14                               True                 False       8
# 15                              False                 False      35
# 16                               True                  True       5
# 17                              False                 False       2
# 18                              False                 False       4
# 19                              False                 False      12
# 20                              False                 False       3
# 21                              False                 False       2
# 22                              False                 False       1
# 23                              False                 False      31
# 24                               True                 False       1
# 25                              False                 False      35
# 26                               True                  True       3
# 27                              False                 False      27
# 28                               True                 False       2
# 29                              False                 False      22
# 30                               True                  True       1
#
#      permutation
# 0   non_permuted
# 1   non_permuted
# 2   non_permuted
# 3   non_permuted
# 4   non_permuted
# 5   non_permuted
# 6   non_permuted
# 7   non_permuted
# 8   non_permuted
# 9   non_permuted
# 10  non_permuted
# 11  non_permuted
# 12  non_permuted
# 13      permuted
# 14      permuted
# 15      permuted
# 16      permuted
# 17      permuted
# 18      permuted
# 19      permuted
# 20      permuted
# 21      permuted
# 22      permuted
# 23      permuted
# 24      permuted
# 25      permuted
# 26      permuted
# 27      permuted
# 28      permuted
# 29      permuted
# 30      permuted

# %%
# save the final enrichment df
final_enrichment_half_baked_df.to_csv(
    "../../data/6.analysis_results/sum_aggregated_feature_group_enrichment_half_baked.csv",
    index=False,
)

final_enrichment_df.to_csv(
    "../../data/6.analysis_results/sum_aggregated_feature_group_enrichment.csv",
    index=False,
)
