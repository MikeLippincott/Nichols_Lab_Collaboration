# %%
import pathlib

import pandas as pd

# %%
input_path = pathlib.Path(
    "../../data/5.converted_data/sum_aggregated_data.parquet"
).resolve(strict=True)

# %%
# read in the data
df = pd.read_parquet(input_path)
df.head()
# Out:
#   Metadata_genotype Metadata_replicate Metadata_side  AreaShape_Area  \
# 0              high                  1             L       -0.178797
# 1              high                  1             R        1.371763
# 2              high                 10             L        1.706234
# 3              high                 10             R        0.771674
# 4              high                 11             L        2.180858
#
#    AreaShape_CentralMoment_0_0  AreaShape_CentralMoment_0_1  \
# 0                    -0.178797                     0.003558
# 1                     1.371763                     0.538195
# 2                     1.706234                     2.652373
# 3                     0.771674                    -1.332747
# 4                     2.180858                     2.142686
#
#    AreaShape_CentralMoment_0_2  AreaShape_CentralMoment_0_3  \
# 0                    -0.386796                     0.280118
# 1                     0.288322                     0.501618
# ...

# %%
# drop the columns that are not needed
uneeded_columns = ["Metadata_replicate", "Metadata_side"]
df = df.drop(columns=uneeded_columns)

# %%
# get the variance of each feature for each genotype
variances = df.groupby("Metadata_genotype").var()
variances
# Out:
#                    AreaShape_Area  AreaShape_CentralMoment_0_0  \
# Metadata_genotype
# high                     0.516762                     0.516762
# unsel                    1.080019                     1.080019
# wt                       0.250290                     0.250290
#
#                    AreaShape_CentralMoment_0_1  AreaShape_CentralMoment_0_2  \
# Metadata_genotype
# high                                  2.361025                     1.147158
# unsel                                 2.315194                     1.569349
# wt                                    0.294862                     0.167498
#
#                    AreaShape_CentralMoment_0_3  AreaShape_CentralMoment_1_0  \
# Metadata_genotype
# high                                  0.716030                     3.855982
# unsel                                 3.864689                     1.239712
# wt                                    0.488715                     0.257372
#
# ...

# %%
# save the per feature per genotype variance data
output_path = pathlib.Path(
    "../results/sum_aggregated_results/sum_aggregated_per_feature_per_genotype_variance.csv"
).resolve()
variances.to_csv(output_path)
