# %%
import pathlib

import pandas as pd

# %%
file_path = pathlib.Path(
    "../../data/5.converted_data/normalized_feature_selected_output.parquet"
).resolve(strict=True)
df = pd.read_parquet(file_path)
df.head()
# Out:
#   Metadata_Image_FileName_OP  Metadata_ObjectNumber  \
# 0         MAX_high_10_L.tiff                      1
# 1         MAX_high_10_R.tiff                      1
# 2         MAX_high_11_L.tiff                      1
# 3         MAX_high_11_R.tiff                      1
# 4         MAX_high_12_L.tiff                      2
#
#    Metadata_Object_ConvertImageToObjects_Number_Object_Number  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Metadata_Object_ConvertImageToObjects_AreaShape_BoundingBoxArea  \
# 0                                            38250.0
# 1                                            34170.0
# 2                                            41736.0
# 3                                            43616.0
# 4                                            25894.0
#
#    Metadata_Object_ConvertImageToObjects_AreaShape_BoundingBoxMaximum_X  \
# 0                                              269.0
# 1                                              208.0
# 2                                              250.0
# 3                                              212.0
# 4                                              283.0
#
#    Metadata_Object_ConvertImageToObjects_AreaShape_BoundingBoxMaximum_Y  \
# 0                                              182.0
# 1                                              245.0
# 2                                              267.0
# 3                                              272.0
# 4                                              155.0
#
#    Metadata_Object_ConvertImageToObjects_AreaShape_BoundingBoxMinimum_X  \
# 0                                               44.0
# 1                                               38.0
# 2                                               62.0
# 3                                               24.0
# 4                                               69.0
#
#    Metadata_Object_ConvertImageToObjects_AreaShape_BoundingBoxMinimum_Y  \
# 0                                               12.0
# 1                                               44.0
# 2                                               45.0
# 3                                               40.0
# 4                                               34.0
#
#    Metadata_Object_ConvertImageToObjects_Location_CenterMassIntensity_X_OP  \
# 0                                         131.546149
# 1                                         106.962058
# 2                                         131.359827
# 3                                         101.069901
# 4                                         164.579054
#
#    Metadata_Object_ConvertImageToObjects_Location_CenterMassIntensity_Y_OP  \
# 0                                         118.641091
# 1                                         162.304190
# 2                                         159.444463
# 3                                         185.486430
# 4                                         105.266522
#
#    ...  Texture_SumEntropy_OP_3_02_256  Texture_SumEntropy_OP_3_03_256  \
# 0  ...                        0.841475                        0.834574
# 1  ...                        0.452480                        0.436138
# 2  ...                        0.494813                        0.490844
# 3  ...                        0.878729                        0.865617
# 4  ...                        0.476768                        0.482674
#
#    Texture_SumVariance_OP_3_00_256  Texture_SumVariance_OP_3_01_256  \
# 0                         1.149186                         1.152200
# 1                         0.112178                         0.131982
# 2                        -0.016140                         0.001041
# 3                         1.120905                         1.140604
# 4                         0.177886                         0.147933
#
#    Texture_SumVariance_OP_3_02_256  Texture_SumVariance_OP_3_03_256  \
# 0                         1.078905                         1.144848
# 1                         0.108602                         0.125700
# 2                        -0.021997                        -0.020992
# 3                         1.074529                         1.117941
# 4                         0.103313                         0.156457
#
#    Texture_Variance_OP_3_00_256  Texture_Variance_OP_3_01_256  \
# 0                      1.040009                      1.025740
# 1                      0.075717                      0.071207
# 2                     -0.033934                     -0.042635
# 3                      1.031585                      1.015172
# 4                      0.111765                      0.107846
#
#    Texture_Variance_OP_3_02_256  Texture_Variance_OP_3_03_256
# 0                      1.045492                      1.027617
# 1                      0.076477                      0.067922
# 2                     -0.034983                     -0.038763
# 3                      1.035150                      1.019188
# 4                      0.117614                      0.108859
#
# [5 rows x 268 columns]

# %% [markdown]
# We want to remove CellProfiler features that do not accurately contribute to the shape variance.
#
#
# Spatial moment features are removed as they are not invariant to rotation and translation.
#
# Central moment features are removed as measurements of size is not of interest.
#
# Normalized moment features are removed as they do not contribute to the shape variance.
#
# EulerNumber is removed as we are not concerned with the number of holes in the shape.
#
# Extent is removed as we do not care about the ratio of pixels in the bounding box to the pixels in the shape.
#
# Orientation is removed as we are not concerned with the angle of the major axis of the shape.
#
# Zernike features are removed as they are not invariant to rotation and translation.
#
# Texturre features are removed as we are not interested in the texture of the shape.

# %%
list_to_drop = [
    "SpatialMoment",
    "CentralMoment",
    "NormalizedMoment",
    "EulerNumber",
    "Extent",
    "Orientation",
    "Zernike",
    "Texture",
]

# %%
# drop columns that contain Metadata
df1 = df.copy()
df1 = df1.drop(columns=[col for col in df1.columns if "Metadata" in col])
columns = df1.columns.to_list()
print(df1.shape)
# if column contains any of the strings in list_to_drop, drop it
for col in list_to_drop:
    columns = [c for c in columns if col not in c]
df1 = df1[columns]
print(df1.shape)
df1["Metadata_genotype"] = df["Metadata_genotype"]
df1["Metadata_replicate"] = df["Metadata_replicate"]
# Out:
# (136, 244)
# (136, 64)

# %%
df1.head()
# Out:
#    AreaShape_Area  AreaShape_Compactness  AreaShape_ConvexArea  \
# 0        1.706234              -1.094663              1.526738
# 1        0.771674              -1.074951              0.753993
# 2        2.180858              -0.296613              2.408620
# 3        2.081557              -1.214322              2.025345
# 4        0.659368              -1.188961              0.504407
#
#    AreaShape_Eccentricity  AreaShape_EquivalentDiameter  AreaShape_FormFactor  \
# 0               -0.364618                      1.604017              1.301326
# 1                0.169009                      0.892807              1.255925
# 2               -2.937313                      1.923791             -0.006871
# 3               -0.835423                      1.858731              1.598489
# 4                0.391980                      0.797707              1.532220
#
#    AreaShape_HuMoment_0  AreaShape_HuMoment_1  AreaShape_HuMoment_2  \
# 0             -0.850517             -0.643917             -0.930476
# 1             -0.679950             -0.573659             -0.915379
# 2             -0.933497             -0.701417             -0.947919
# 3             -0.915258             -0.669286             -0.975004
# 4             -0.557646             -0.511615             -0.797396
#
#    AreaShape_HuMoment_3  ...  RadialDistribution_MeanFrac_OP_1of4  \
# 0             -0.658509  ...                            -1.316829
# 1             -0.624424  ...                            -1.180881
# 2             -0.655172  ...                             1.434761
# 3             -0.666798  ...                            -1.290907
# 4             -0.553501  ...                            -1.120925
#
#    RadialDistribution_MeanFrac_OP_2of4  RadialDistribution_MeanFrac_OP_3of4  \
# 0                            -1.414181                            -1.081362
# 1                            -1.336964                            -1.518430
# 2                             0.333079                            -0.424506
# 3                            -1.375732                            -1.366826
# 4                            -1.311740                            -1.176903
#
#    RadialDistribution_MeanFrac_OP_4of4  RadialDistribution_RadialCV_OP_1of4  \
# 0                             1.472547                             0.721204
# 1                             1.639641                             1.061081
# 2                            -0.325401                             1.638487
# 3                             1.782309                            -0.433301
# 4                             1.365780                             0.003005
#
#    RadialDistribution_RadialCV_OP_2of4  RadialDistribution_RadialCV_OP_3of4  \
# 0                             1.019337                             1.413652
# 1                             0.230001                             0.798123
# 2                             1.213389                             0.152224
# 3                            -0.054361                             0.907682
# 4                             0.407067                             1.031950
#
#    RadialDistribution_RadialCV_OP_4of4  Metadata_genotype  Metadata_replicate
# 0                             1.432583               high                  10
# 1                             1.372333               high                  10
# 2                             0.230334               high                  11
# 3                             1.138530               high                  11
# 4                             1.072205               high                  12
#
# [5 rows x 66 columns]

# %%
# save the dataframe
df_path = pathlib.Path(
    "../../data/5.converted_data/non_aggregated_manual_feature_selected_data.parquet"
)
df1.to_parquet(df_path)
