# %%
suppressWarnings(suppressPackageStartupMessages(library(ggplot2)))
suppressWarnings(suppressPackageStartupMessages(library(dplyr)))
suppressWarnings(suppressPackageStartupMessages(library(tidyr)))
suppressWarnings(suppressPackageStartupMessages(library(arrow)))
suppressWarnings(suppressPackageStartupMessages(library(umap)))
# Load necessary packages
suppressWarnings(suppressPackageStartupMessages(library(factoextra)))

# %%
# set path to the data
file_path <- file.path("..","..","data", "5.converted_data","sum_aggregated_data.parquet")
# set path to figures
fig_path <- file.path("..","figures","sum_aggregated")
# create the directory if it does not exist
if (!dir.exists(fig_path)) {
    dir.create(fig_path, recursive = TRUE)
}
pca_file_path <- file.path("..","..","data", "6.analysis_results","sum_aggregated_pca.parquet")

# read the data
df <- arrow::read_parquet(file_path)
df$Metadata_genotype <- gsub("wt", "Wild Type", df$Metadata_genotype)
df$Metadata_genotype <- gsub("unsel", "Mid-Severity", df$Metadata_genotype)
df$Metadata_genotype <- gsub("high", "High-Severity", df$Metadata_genotype)
df$Metadata_genotype <- factor(
    df$Metadata_genotype, 
    levels = c("Wild Type", "Mid-Severity", "High-Severity")
)
head(df)
# Out:
#   Metadata_genotype Metadata_replicate Metadata_side AreaShape_Area
# 1 High-Severity     1                  L             -0.1787974
# 2 High-Severity     1                  R              1.3717630
# 3 High-Severity     10                 L              1.7062336
# 4 High-Severity     10                 R              0.7716744
# 5 High-Severity     11                 L              2.1808575
# 6 High-Severity     11                 R              2.0815568
#   AreaShape_CentralMoment_0_0 AreaShape_CentralMoment_0_1
# 1 -0.1787974                   0.003557521
# 2  1.3717630                   0.538195037
# 3  1.7062336                   2.652373336
# 4  0.7716744                  -1.332747275
# 5  2.1808575                   2.142685571
# 6  2.0815568                  -0.880954492
#   AreaShape_CentralMoment_0_2 AreaShape_CentralMoment_0_3
# 1 -0.3867965                   0.2801180
# 2  0.2883216                   0.5016182
# 3  3.2804249                  -1.9929659
# 4  0.1643035                   0.2443713
# 5  1.8380375                  -0.0775148
# 6  1.0149013                   0.6606970
#   AreaShape_CentralMoment_1_0 AreaShape_CentralMoment_1_1 ⋯
# 1 0.037997585                  0.4340460                  ⋯
# 2 4.163832754                 -1.3619197                  ⋯
# 3 0.184629766                 -1.4043758                  ⋯
# 4 0.173760455                 -1.8851436                  ⋯
# 5 0.008650445                  0.8765967                  ⋯
# 6 3.593763273                 -1.4179216                  ⋯
#   Texture_SumEntropy_OP_3_02_256 Texture_SumEntropy_OP_3_03_256
# 1 -0.6277618                     -0.6449902
# 2  0.4195514                      0.4069176
# 3  0.8414748                      0.8345736
# 4  0.4524796                      0.4361385
# 5  0.4948130                      0.4908441
# 6  0.8787288                      0.8656168
#   Texture_SumVariance_OP_3_00_256 Texture_SumVariance_OP_3_01_256
# 1 -0.90335362                     -0.8909394
# 2 -0.18835794                     -0.1591142
# 3  1.14918564                      1.1522001
# 4  0.11217819                      0.1319819
# 5 -0.01613966                      0.0010415
# 6  1.12090459                      1.1406044
#   Texture_SumVariance_OP_3_02_256 Texture_SumVariance_OP_3_03_256
# 1 -0.89699453                     -0.90287010
# 2 -0.18961488                     -0.18630752
# 3  1.07890507                      1.14484796
# 4  0.10860250                      0.12569959
# 5 -0.02199706                     -0.02099207
# 6  1.07452904                      1.11794134
#   Texture_Variance_OP_3_00_256 Texture_Variance_OP_3_01_256
# 1 -0.89614520                  -0.89844840
# 2 -0.21898136                  -0.22575440
# 3  1.04000878                   1.02573996
# 4  0.07571690                   0.07120688
# 5 -0.03393425                  -0.04263493
# 6  1.03158516                   1.01517198
#   Texture_Variance_OP_3_02_256 Texture_Variance_OP_3_03_256
# 1 -0.89887968                  -0.89660930
# 2 -0.21907311                  -0.22513426
# 3  1.04549223                   1.02761705
# 4  0.07647711                   0.06792193
# 5 -0.03498345                  -0.03876252
# 6  1.03514983                   1.01918842

# %%
# get the features
features <- colnames(df)
# write features to a file as csv
write.csv(features, file = "../../data/5.converted_data/selected_features.csv", row.names = FALSE)

# %%
# split the data into metadata and features
metadata_df <- df %>% select(contains("Metadata"))
features_df <- df %>% select(-contains("Metadata"))
print(dim(metadata_df))
print(dim(features_df))
# Out:
# [1] 83  3
# [1]  83 244

# %% [markdown]
# ### UMAP of genotype

# %%
# umap
width <- 7
height <- 5
options(repr.plot.width = width, repr.plot.height = height)
umap_df <- umap::umap((features_df), n_neighbors = 7, min_dist = 0.7, n_components = 2, metric = "cosine")
umap_df <- as.data.frame(umap_df$layout)
colnames(umap_df) <- c("UMAP0", "UMAP1")
umap_df <- cbind(metadata_df, umap_df)

# plot umap
umap_plot <- (
    ggplot(umap_df, aes(x = UMAP0, y = UMAP1, color = Metadata_genotype))
    + geom_point(size = 2)

    + theme_bw()
    + guides(color = guide_legend(title = "Genotype"))
)
umap_plot
# save the plot
ggsave("sum_aggregated_umap_plot_genotype.png", path = file.path(fig_path), width = width, height = height, units = "in", dpi = 600)
# Out:
# plot without title

# %%
# Apply PCA
res.pca <- prcomp(features_df, scale = TRUE)

# Create scree plot
scree_plot <- fviz_eig(res.pca, addlabels = TRUE, ylim = c(0, 50))
scree_plot <- (
    scree_plot
    + theme_bw()
    # title centered
    + theme(plot.title = element_text(hjust = 0.5))
)
scree_plot
# save the plot
ggsave("sum_aggregated_scree_plot.png", path = file.path(fig_path), width = width, height = height, units = "in", dpi = 600)
# Out:
# plot without title

# %% [markdown]
# ### PCA with genotype

# %%
# pca analysis
pca_df <- as.data.frame(res.pca$x)
pca_df <- cbind(metadata_df, pca_df)

# plot pca
pca_plot <- (
    ggplot(pca_df, aes(x = PC1, y = PC2, color = Metadata_genotype))
    + geom_point()
    + theme_bw()
    + guides(color = guide_legend(title = "Genotype"))
)
pca_plot
# save the plot
ggsave("sum_aggregated_pca_plot_genotype.png", path = file.path(fig_path), width = width, height = height, units = "in", dpi = 600)
# Out:
# plot without title

# %%
# save the pca results as a parquet file
arrow::write_parquet(pca_df, pca_file_path)
