# %%
import pathlib

import numpy as np
import pandas as pd

# %%
file_path = pathlib.Path(
    "../../data/6.analysis_results/non_aggregated_levene_test_results.csv"
).resolve(strict=True)


df = pd.read_csv(file_path, index_col=0).reset_index(drop=True)
df
# Out:
#                           feature  levene_statistic  levene_p_value  \
# 0                  AreaShape_Area          0.598153        0.441621
# 1                  AreaShape_Area          9.724137        0.002509
# 2                  AreaShape_Area         19.467794        0.000025
# 3     AreaShape_CentralMoment_0_0          0.598153        0.441621
# 4     AreaShape_CentralMoment_0_0          9.724137        0.002509
# ..                            ...               ...             ...
# 727  Texture_Variance_OP_3_02_256          9.882766        0.002323
# 728  Texture_Variance_OP_3_02_256         19.415515        0.000025
# 729  Texture_Variance_OP_3_03_256          0.058614        0.809336
# 730  Texture_Variance_OP_3_03_256          9.861381        0.002347
# 731  Texture_Variance_OP_3_03_256         18.878581        0.000032
#
#              group  holm_bonferroni_p_value
# 0    high_vs_unsel                 0.441621
# 1       high_vs_wt                 0.005018
# 2      unsel_vs_wt                 0.000074
# 3    high_vs_unsel                 0.441621
# 4       high_vs_wt                 0.005018
# ..             ...                      ...
# 727     high_vs_wt                 0.004646
# 728    unsel_vs_wt                 0.000076
# 729  high_vs_unsel                 0.809336
# 730     high_vs_wt                 0.004695
# 731    unsel_vs_wt                 0.000096
#
# [732 rows x 5 columns]

# %%
# subset the data
high_vs_wt = df.loc[df["group"] == "high_vs_wt"]
unsel_vs_wt = df.loc[df["group"] == "unsel_vs_wt"]
high_vs_unsel = df.loc[df["group"] == "high_vs_unsel"]

high_vs_wt.rename(
    columns={
        "levene_p_value": "high_vs_wt_levene_p_value",
        "holm_bonferroni_p_value": "high_vs_wt_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)
unsel_vs_wt.rename(
    columns={
        "levene_p_value": "unsel_vs_wt_levene_p_value",
        "holm_bonferroni_p_value": "unsel_vs_wt_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)
high_vs_unsel.rename(
    columns={
        "levene_p_value": "high_vs_unsel_levene_p_value",
        "holm_bonferroni_p_value": "high_vs_unsel_levene_p_value_holm_bonferroni",
    },
    inplace=True,
)


# drop columns
high_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
unsel_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
high_vs_unsel.drop(columns=["group", "levene_statistic"], inplace=True)


# combine the data
combined_df = pd.merge(high_vs_wt, unsel_vs_wt, on="feature")
combined_df = pd.merge(combined_df, high_vs_unsel, on="feature")
combined_df.head()
# Out:
# /tmp/ipykernel_819648/3310347519.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_wt.rename(
# /tmp/ipykernel_819648/3310347519.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsel_vs_wt.rename(
# /tmp/ipykernel_819648/3310347519.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_unsel.rename(
# /tmp/ipykernel_819648/3310347519.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
# /tmp/ipykernel_819648/3310347519.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsel_vs_wt.drop(columns=["group", "levene_statistic"], inplace=True)
# /tmp/ipykernel_819648/3310347519.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_vs_unsel.drop(columns=["group", "levene_statistic"], inplace=True)
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area               2.508889e-03
# 1  AreaShape_CentralMoment_0_0               2.508889e-03
# 2  AreaShape_CentralMoment_0_1               2.183935e-07
# 3  AreaShape_CentralMoment_0_2               1.936676e-09
# 4  AreaShape_CentralMoment_0_3               1.392974e-03
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                               5.017778e-03                    0.000025
# 1                               5.017778e-03                    0.000025
# 2                               6.551805e-07                    0.003954
# 3                               5.810029e-09                    0.000574
# 4                               4.178921e-03                    0.002091
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.000074                      0.441621
# 1                                    0.000074                      0.441621
# 2                                    0.007909                      0.045573
# 3                                    0.001149                      0.191473
# 4                                    0.004182                      0.510387
#
#    high_vs_unsel_levene_p_value_holm_bonferroni
# 0                                      0.441621
# 1                                      0.441621
# 2                                      0.045573
# 3                                      0.191473
# 4                                      0.510387

# %%
variance_df_path = pathlib.Path(
    "../../data/6.analysis_results/non_aggregated_variance_results_each_feature.csv"
).resolve(strict=True)
variance_df = pd.read_csv(variance_df_path)
variance_df.head()
# Out:
#   Metadata_genotype                      feature  variance
# 0              high               AreaShape_Area  0.516762
# 1              high  AreaShape_CentralMoment_0_0  0.516762
# 2              high  AreaShape_CentralMoment_0_1  2.361025
# 3              high  AreaShape_CentralMoment_0_2  1.147158
# 4              high  AreaShape_CentralMoment_0_3  0.716030

# %%
# replace metadata genotype with the correct group
variance_df["Metadata_genotype"].replace(
    {"high": "High-Severity", "unsel": "Mid-Severity", "wt": "Wild Type"}, inplace=True
)
variance_df.head()
# Out:
#   Metadata_genotype                      feature  variance
# 0     High-Severity               AreaShape_Area  0.516762
# 1     High-Severity  AreaShape_CentralMoment_0_0  0.516762
# 2     High-Severity  AreaShape_CentralMoment_0_1  2.361025
# 3     High-Severity  AreaShape_CentralMoment_0_2  1.147158
# 4     High-Severity  AreaShape_CentralMoment_0_3  0.716030

# %%
high_severity = variance_df.loc[variance_df["Metadata_genotype"] == "High-Severity"]
mid_severity = variance_df.loc[variance_df["Metadata_genotype"] == "Mid-Severity"]
wt = variance_df.loc[variance_df["Metadata_genotype"] == "Wild Type"]

# rename the columns
high_severity.rename(columns={"variance": "high_severity_variance"}, inplace=True)
mid_severity.rename(columns={"variance": "mid_severity_variance"}, inplace=True)
wt.rename(columns={"variance": "wild_type_severity_variance"}, inplace=True)

# drop columns
high_severity.drop(columns=["Metadata_genotype"], inplace=True)
mid_severity.drop(columns=["Metadata_genotype"], inplace=True)
wt.drop(columns=["Metadata_genotype"], inplace=True)

high_severity.reset_index(drop=True, inplace=True)
mid_severity.reset_index(drop=True, inplace=True)
wt.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_819648/421898067.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_severity.rename(columns={"variance": "high_severity_variance"}, inplace=True)
# /tmp/ipykernel_819648/421898067.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_severity.rename(columns={"variance": "mid_severity_variance"}, inplace=True)
# /tmp/ipykernel_819648/421898067.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt.rename(columns={"variance": "wild_type_severity_variance"}, inplace=True)
# /tmp/ipykernel_819648/421898067.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_severity.drop(columns=["Metadata_genotype"], inplace=True)
# /tmp/ipykernel_819648/421898067.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_severity.drop(columns=["Metadata_genotype"], inplace=True)
# /tmp/ipykernel_819648/421898067.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wt.drop(columns=["Metadata_genotype"], inplace=True)

# %%
all_severities = pd.merge(
    mid_severity, high_severity, left_on="feature", right_on="feature"
)
all_severities = pd.merge(all_severities, wt, left_on="feature", right_on="feature")
combined_df = pd.merge(combined_df, all_severities, on="feature")
combined_df.head()
# Out:
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area               2.508889e-03
# 1  AreaShape_CentralMoment_0_0               2.508889e-03
# 2  AreaShape_CentralMoment_0_1               2.183935e-07
# 3  AreaShape_CentralMoment_0_2               1.936676e-09
# 4  AreaShape_CentralMoment_0_3               1.392974e-03
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                               5.017778e-03                    0.000025
# 1                               5.017778e-03                    0.000025
# 2                               6.551805e-07                    0.003954
# 3                               5.810029e-09                    0.000574
# 4                               4.178921e-03                    0.002091
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.000074                      0.441621
# 1                                    0.000074                      0.441621
# 2                                    0.007909                      0.045573
# 3                                    0.001149                      0.191473
# 4                                    0.004182                      0.510387
#
#    high_vs_unsel_levene_p_value_holm_bonferroni  mid_severity_variance  \
# 0                                      0.441621               0.698963
# 1                                      0.441621               0.698963
# 2                                      0.045573               1.251097
# 3                                      0.191473               0.958284
# 4                                      0.510387               1.997020
#
#    high_severity_variance  wild_type_severity_variance
# 0                0.516762                     0.157703
# 1                0.516762                     0.157703
# 2                2.361025                     0.125912
# 3                1.147158                     0.100625
# 4                0.716030                     0.226913

# %%
# make a new column that contains permutation test results for each feature
np.random.seed(0)
n_permutations = 1000
# permute each column
permuted_df = combined_df.copy()
for column in permuted_df.columns:
    if column != "feature":
        permuted_df[column] = np.random.permutation(permuted_df[column].values)

# %%
combined_df.head()
# Out:
#                        feature  high_vs_wt_levene_p_value  \
# 0               AreaShape_Area               2.508889e-03
# 1  AreaShape_CentralMoment_0_0               2.508889e-03
# 2  AreaShape_CentralMoment_0_1               2.183935e-07
# 3  AreaShape_CentralMoment_0_2               1.936676e-09
# 4  AreaShape_CentralMoment_0_3               1.392974e-03
#
#    high_vs_wt_levene_p_value_holm_bonferroni  unsel_vs_wt_levene_p_value  \
# 0                               5.017778e-03                    0.000025
# 1                               5.017778e-03                    0.000025
# 2                               6.551805e-07                    0.003954
# 3                               5.810029e-09                    0.000574
# 4                               4.178921e-03                    0.002091
#
#    unsel_vs_wt_levene_p_value_holm_bonferroni  high_vs_unsel_levene_p_value  \
# 0                                    0.000074                      0.441621
# 1                                    0.000074                      0.441621
# 2                                    0.007909                      0.045573
# 3                                    0.001149                      0.191473
# 4                                    0.004182                      0.510387
#
#    high_vs_unsel_levene_p_value_holm_bonferroni  mid_severity_variance  \
# 0                                      0.441621               0.698963
# 1                                      0.441621               0.698963
# 2                                      0.045573               1.251097
# 3                                      0.191473               0.958284
# 4                                      0.510387               1.997020
#
#    high_severity_variance  wild_type_severity_variance
# 0                0.516762                     0.157703
# 1                0.516762                     0.157703
# 2                2.361025                     0.125912
# 3                1.147158                     0.100625
# 4                0.716030                     0.226913

# %% [markdown]
# We now identify which complexes match the exact hypothesis of the problem.
# The hypothesis is that the high-severity and wild type genotype complexes have less morphology variance than that of the unselected severity genotype complexes.
# In addition there should be no statistically significant difference between the variance of morphology high-severity and wild type genotype complexes.

# %%
dict_of_dfs = {"non_permuted": combined_df, "permuted": permuted_df}
output_dfs = {"non_permuted": "", "permuted": ""}
for data_shuffle_df in dict_of_dfs:
    df = dict_of_dfs[data_shuffle_df]
    # variance logic
    # wt < mid
    # mid > high
    df["variance_pattern_bool"] = np.where(
        (df["high_severity_variance"] < df["mid_severity_variance"])
        & (df["wild_type_severity_variance"] < df["mid_severity_variance"]),
        True,
        False,
    )
    # levene logic
    # high_vs_unsel <0.05
    # wt_vs_unsel <0.05
    # high_vs_wt >0.05
    df["significance_bool_holm_bonferroni"] = np.where(
        (df["high_vs_unsel_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["unsel_vs_wt_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["high_vs_wt_levene_p_value_holm_bonferroni"] > 0.05),
        True,
        False,
    )

    df["significance_bool_half_baked_holm_bonferroni"] = np.where(
        (df["high_vs_unsel_levene_p_value_holm_bonferroni"] < 0.05)
        & (df["unsel_vs_wt_levene_p_value_holm_bonferroni"] < 0.05),
        True,
        False,
    )

    df["hypothesis_test_bool"] = np.where(
        (df["variance_pattern_bool"] == True)
        & (df["significance_bool_holm_bonferroni"] == True),
        True,
        False,
    )
    df["hypothesis_test_bool_half_baked"] = np.where(
        (df["variance_pattern_bool"] == True)
        & (df["significance_bool_half_baked_holm_bonferroni"] == True),
        True,
        False,
    )

    output_dfs[data_shuffle_df] = df

# %%
list_of_enrichment_dfs = []
for data_shuffle_df in output_dfs:
    df = output_dfs[data_shuffle_df]
    # split the feature column
    df[
        [
            "feature_group",
            "measurement",
            "bone",
            "parameter1",
            "parameter2",
            "parameter3",
        ]
    ] = df["feature"].str.split("_", expand=True)

    # get counts of each feature group and the hypothesis test bool
    hypothesis_tests_half_baked_df = (
        df.groupby(
            [
                "feature_group",
                "variance_pattern_bool",
                "significance_bool_half_baked_holm_bonferroni",
                "hypothesis_test_bool_half_baked",
            ]
        )
        .size()
        .reset_index(name="counts")
    )
    hypothesis_tests_half_baked_df["permutation"] = data_shuffle_df
    list_of_enrichment_dfs.append(hypothesis_tests_half_baked_df)
final_enrichment_half_baked_df = pd.concat(list_of_enrichment_dfs)
final_enrichment_half_baked_df.reset_index(drop=True, inplace=True)

# %%
list_of_enrichment_dfs = []
for data_shuffle_df in output_dfs:
    df = output_dfs[data_shuffle_df]
    # split the feature column
    df[
        [
            "feature_group",
            "measurement",
            "bone",
            "parameter1",
            "parameter2",
            "parameter3",
        ]
    ] = df["feature"].str.split("_", expand=True)

    # get counts of each feature group and the hypothesis test bool
    hypothesis_tests_df = (
        df.groupby(
            [
                "feature_group",
                "variance_pattern_bool",
                "significance_bool_holm_bonferroni",
                "hypothesis_test_bool",
            ]
        )
        .size()
        .reset_index(name="counts")
    )
    hypothesis_tests_df["permutation"] = data_shuffle_df
    list_of_enrichment_dfs.append(hypothesis_tests_df)
final_enrichment_df = pd.concat(list_of_enrichment_dfs)
final_enrichment_df.reset_index(drop=True, inplace=True)

# %%
final_enrichment_half_baked_df.head(60)
# Out:
#          feature_group  variance_pattern_bool  \
# 0            AreaShape                  False
# 1            AreaShape                  False
# 2            AreaShape                   True
# 3            AreaShape                   True
# 4          Granularity                  False
# 5          Granularity                  False
# 6          Granularity                   True
# 7            Intensity                  False
# 8            Intensity                   True
# 9            Neighbors                   True
# 10  RadialDistribution                  False
# 11  RadialDistribution                  False
# 12  RadialDistribution                   True
# 13  RadialDistribution                   True
# 14             Texture                  False
# 15             Texture                  False
# 16             Texture                   True
# 17             Texture                   True
# 18           AreaShape                  False
# 19           AreaShape                  False
# 20           AreaShape                   True
# 21           AreaShape                   True
# 22         Granularity                  False
# 23         Granularity                   True
# 24         Granularity                   True
# 25           Intensity                  False
# 26           Intensity                  False
# 27           Intensity                   True
# 28           Neighbors                  False
# 29           Neighbors                  False
# 30  RadialDistribution                  False
# 31  RadialDistribution                  False
# 32  RadialDistribution                   True
# 33  RadialDistribution                   True
# 34             Texture                  False
# 35             Texture                  False
# 36             Texture                   True
# 37             Texture                   True
#
#     significance_bool_half_baked_holm_bonferroni  \
# 0                                          False
# 1                                           True
# 2                                          False
# 3                                           True
# 4                                          False
# 5                                           True
# 6                                          False
# 7                                          False
# 8                                          False
# 9                                          False
# 10                                         False
# 11                                          True
# 12                                         False
# 13                                          True
# 14                                         False
# 15                                          True
# 16                                         False
# 17                                          True
# 18                                         False
# 19                                          True
# 20                                         False
# 21                                          True
# 22                                         False
# 23                                         False
# 24                                          True
# 25                                         False
# 26                                          True
# 27                                         False
# 28                                         False
# 29                                          True
# 30                                         False
# 31                                          True
# 32                                         False
# 33                                          True
# 34                                         False
# 35                                          True
# 36                                         False
# 37                                          True
#
#     hypothesis_test_bool_half_baked  counts   permutation
# 0                             False      33  non_permuted
# 1                             False      19  non_permuted
# 2                             False      41  non_permuted
# 3                              True       5  non_permuted
# 4                             False       3  non_permuted
# 5                             False       2  non_permuted
# 6                             False       1  non_permuted
# 7                             False      14  non_permuted
# 8                             False       1  non_permuted
# 9                             False       3  non_permuted
# 10                            False      48  non_permuted
# 11                            False       5  non_permuted
# 12                            False      16  non_permuted
# 13                             True       1  non_permuted
# 14                            False      33  non_permuted
# 15                            False       3  non_permuted
# 16                            False      11  non_permuted
# 17                             True       5  non_permuted
# 18                            False      50      permuted
# 19                            False      13      permuted
# 20                            False      29      permuted
# 21                             True       6      permuted
# 22                            False       2      permuted
# 23                            False       2      permuted
# 24                             True       2      permuted
# 25                            False       9      permuted
# 26                            False       2      permuted
# 27                            False       4      permuted
# 28                            False       2      permuted
# 29                            False       1      permuted
# 30                            False      35      permuted
# 31                            False       7      permuted
# 32                            False      25      permuted
# 33                             True       3      permuted
# 34                            False      30      permuted
# 35                            False       4      permuted
# 36                            False      14      permuted
# 37                             True       4      permuted

# %%
final_enrichment_df.head(60)
# Out:
#          feature_group  variance_pattern_bool  \
# 0            AreaShape                  False
# 1            AreaShape                   True
# 2            AreaShape                   True
# 3          Granularity                  False
# 4          Granularity                   True
# 5            Intensity                  False
# 6            Intensity                   True
# 7            Neighbors                   True
# 8   RadialDistribution                  False
# 9   RadialDistribution                   True
# 10             Texture                  False
# 11             Texture                   True
# 12             Texture                   True
# 13           AreaShape                  False
# 14           AreaShape                  False
# 15           AreaShape                   True
# 16           AreaShape                   True
# 17         Granularity                  False
# 18         Granularity                   True
# 19           Intensity                  False
# 20           Intensity                  False
# 21           Intensity                   True
# 22           Neighbors                  False
# 23  RadialDistribution                  False
# 24  RadialDistribution                  False
# 25  RadialDistribution                   True
# 26  RadialDistribution                   True
# 27             Texture                  False
# 28             Texture                  False
# 29             Texture                   True
# 30             Texture                   True
#
#     significance_bool_holm_bonferroni  hypothesis_test_bool  counts  \
# 0                               False                 False      52
# 1                               False                 False      42
# 2                                True                  True       4
# 3                               False                 False       5
# 4                               False                 False       1
# 5                               False                 False      14
# 6                               False                 False       1
# 7                               False                 False       3
# 8                               False                 False      53
# 9                               False                 False      17
# 10                              False                 False      36
# 11                              False                 False      12
# 12                               True                  True       4
# 13                              False                 False      57
# 14                               True                 False       6
# 15                              False                 False      33
# 16                               True                  True       2
# 17                              False                 False       2
# 18                              False                 False       4
# 19                              False                 False       9
# 20                               True                 False       2
# 21                              False                 False       4
# 22                              False                 False       3
# 23                              False                 False      38
# 24                               True                 False       4
# 25                              False                 False      27
# 26                               True                  True       1
# 27                              False                 False      33
# 28                               True                 False       1
# 29                              False                 False      16
# 30                               True                  True       2
#
#      permutation
# 0   non_permuted
# 1   non_permuted
# 2   non_permuted
# 3   non_permuted
# 4   non_permuted
# 5   non_permuted
# 6   non_permuted
# 7   non_permuted
# 8   non_permuted
# 9   non_permuted
# 10  non_permuted
# 11  non_permuted
# 12  non_permuted
# 13      permuted
# 14      permuted
# 15      permuted
# 16      permuted
# 17      permuted
# 18      permuted
# 19      permuted
# 20      permuted
# 21      permuted
# 22      permuted
# 23      permuted
# 24      permuted
# 25      permuted
# 26      permuted
# 27      permuted
# 28      permuted
# 29      permuted
# 30      permuted

# %%
# save the final enrichment df
final_enrichment_half_baked_df.to_csv(
    "../../data/6.analysis_results/non_aggregated_feature_group_enrichment_half_baked.csv",
    index=False,
)

final_enrichment_df.to_csv(
    "../../data/6.analysis_results/non_aggregated_feature_group_enrichment.csv",
    index=False,
)
