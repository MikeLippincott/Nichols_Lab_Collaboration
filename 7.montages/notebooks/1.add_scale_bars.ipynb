# %%
import pathlib

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tifffile as tf  # write tiff files
from PIL import Image  # read tiff files
from toml import load
from tqdm import tqdm  # progress bar

# %%
path = pathlib.Path("../../data/7.montage_images/individual_images/").resolve()
# get the list of all the files in the directory
files = list(path.glob("*.png"))

# %%
for image_path in files:
    image_path = str(image_path)
    print(image_path)
    # open the image
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    # image to array
    image_array = np.array(image)
    resolution = 1.6585  # pixels per micrometer
    # get the image size
    image_size = image_array.shape
    scale_bar_length = 50  # in micrometers
    scale_bar_height = 10  # in pixels
    padding = 10  # in pixels
    # get the bottom right most corner based on scale 1 % of pixels
    scale_bar_x = image_size[1] - (scale_bar_length / resolution) - padding - padding
    scale_bar_y = image_size[0] - (scale_bar_height) - padding
    print(scale_bar_x, scale_bar_y)
    # draw the scale bar
    new = cv2.rectangle(
        image_array,
        (int(scale_bar_x), int(scale_bar_y)),
        (image_size[1] - padding, image_size[0] - padding),
        (255, 255, 255),
        -1,
    )
    # show the image
    # plt.imshow(new)
    # plt.show()
    # save the image with the scale bar via cv2
    cv2.imwrite(image_path, new)
# Out:
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_6_R.png
# 231.85227615315043 278
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_11_R.png
# 281.85227615315046 290
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_5_R.png
# 345.85227615315046 271
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_10_L.png
# 275.85227615315046 366
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_4_R.png
# 449.85227615315046 444
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_8_L.png
# 233.85227615315043 194
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_3_L.png
# 357.85227615315046 448
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_14_R.png
# 193.85227615315043 270
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_2_L.png
# 259.85227615315046 420
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_8_L.png
# 331.85227615315046 414
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_1_R.png
# 359.85227615315046 342
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_3_R.png
# 385.85227615315046 290
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_11_L.png
# 267.85227615315046 296
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_3_R.png
# 201.85227615315043 306
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_13_L.png
# 153.85227615315043 258
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_4_R.png
# 269.85227615315046 309
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_12_L.png
# 285.85227615315046 150
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_9_R.png
# 363.85227615315046 402
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_6_L.png
# 319.85227615315046 358
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_5_L.png
# 266.85227615315046 347
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_13_L.png
# 235.85227615315043 432
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_5_R.png
# 255.85227615315046 236
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_12_L.png
# 265.85227615315046 284
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_4_L.png
# 257.85227615315046 340
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_10_R.png
# 302.85227615315046 284
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_1_R.png
# 314.85227615315046 275
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_14_R.png
# 363.85227615315046 344
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_11_R.png
# 310.85227615315046 305
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_5_R.png
# 255.85227615315046 342
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_8_R.png
# 365.85227615315046 284
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_14_L.png
# 267.85227615315046 354
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_14_L.png
# 241.85227615315046 395
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_6_L.png
# 313.85227615315046 372
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_12_L.png
# 219.85227615315043 342
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_9_L.png
# 235.85227615315043 172
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_12_R.png
# 205.85227615315043 278
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_7_R.png
# 296.85227615315046 235
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_4_R.png
# 255.85227615315046 224
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_2_R.png
# 311.85227615315046 296
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_6_R.png
# 368.85227615315046 328
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_12_R.png
# 292.85227615315046 279
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_9_L.png
# 441.85227615315046 482
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_1_L.png
# 281.85227615315046 328
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_3_R.png
# 299.85227615315046 277
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_8_R.png
# 315.85227615315046 289
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_2_R.png
# 231.85227615315043 260
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_1_R.png
# 195.85227615315043 332
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_11_R.png
# 189.85227615315043 290
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_1_L.png
# 285.85227615315046 372
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_11_L.png
# 369.85227615315046 406
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_14_L.png
# 215.85227615315043 252
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_4_L.png
# 225.85227615315043 244
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_1_L.png
# 267.85227615315046 226
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_8_L.png
# 227.85227615315043 341
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_9_R.png
# 195.85227615315043 252
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_3_L.png
# 237.85227615315046 288
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_13_R.png
# 275.85227615315046 293
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_9_L.png
# 211.85227615315043 440
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_5_L.png
# 347.85227615315046 382
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_7_L.png
# 181.85227615315043 361
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_10_R.png
# 199.85227615315043 264
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_7_L.png
# 285.85227615315046 328
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_10_L.png
# 224.85227615315043 386
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_14_R.png
# 292.85227615315046 346
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_7_L.png
# 203.85227615315043 288
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_10_R.png
# 361.85227615315046 336
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_10_L.png
# 247.85227615315046 182
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_5_L.png
# 261.85227615315046 286
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_9_R.png
# 405.85227615315046 284
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_13_L.png
# 313.85227615315046 340
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_2_L.png
# 241.85227615315046 250
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_6_L.png
# 205.85227615315043 198
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_7_R.png
# 173.85227615315043 210
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_13_R.png
# 119.85227615315043 266
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_2_L.png
# 297.85227615315046 422
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_7_R.png
# 341.85227615315046 292
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_wt_3_L.png
# 238.85227615315046 338
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_4_L.png
# 267.85227615315046 234
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_6_R.png
# 223.85227615315043 374
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_13_R.png
# 355.85227615315046 370
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_2_R.png
# 331.85227615315046 318
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_high_8_R.png
# 217.85227615315043 272
# /home/lippincm/Documents/Nichols_Lab_Collaboration/data/7.montage_images/individual_images/MAX_unsel_12_R.png
# 313.85227615315046 358
